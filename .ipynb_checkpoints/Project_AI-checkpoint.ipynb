# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import BayesianRidge, LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn import model_selection

# %%
db = pd.read_csv('HappinessAlcoholConsumption.csv')

# %% [markdown]
# ## Pré-Processamento

# %% [markdown]
# ### O banco de dados não tem nenhum dado faltando, como mostrado abaixo

# %%
db.isnull().sum()
# Out:
# Country             0
# Region              0
# Hemisphere          0
# HappinessScore      0
# HDI                 0
# GDP_PerCapita       0
# Beer_PerCapita      0
# Spirit_PerCapita    0
# Wine_PerCapita      0
# dtype: int64

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
# Country             122 non-null object
# Region              122 non-null object
# Hemisphere          122 non-null object
# HappinessScore      122 non-null int64
# HDI                 122 non-null int64
# GDP_PerCapita       122 non-null int64
# Beer_PerCapita      122 non-null int64
# Spirit_PerCapita    122 non-null int64
# Wine_PerCapita      122 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 8.7+ KB

# %% [markdown]
# ### Utilizando *One Hot Encoding* para converter as colunas do tipo *object* para *inteiro*

# %%
db['Country'] = db['Country'].astype('category')
db['Region'] = db['Region'].astype('category')
db['Hemisphere'] = db['Hemisphere'].astype('category')
db['Country'] = db['Country'].cat.codes
db['Region'] = db['Region'].cat.codes
db['Hemisphere'] = db['Hemisphere'].cat.codes

# %% [markdown]
# ### Visualizando a base de dados

# %%
db
# Out:
#      Country  Region  Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0         32       8           1            7526  928          53579
# 1        103       8           1            7509  943          79866
# 2         49       8           1            7501  933          60530
# 3         81       8           1            7498  951          70890
# 4         38       8           1            7413  918          43433
# 5         20       5           1            7404  922          42349
# 6         76       8           1            7339  928          45638
# 7         77       0           3            7334  915          40332
# 8          4       0           3            7313  938          49897
# 9        102       8           1            7291  932          51845
# 10        51       4           1            7267  902          37181
# 11         5       8           1            7119  906          44731
# 12       115       5           1            7104  922          57589
# 13        26       3           1            7087  791          11733
# 14        42       8           1            6994  934          42233
# 15        15       3           0            6952  758           8639
# 16         9       8           1            6929  915          41261
# 17        50       8           1            6907  934          64100
# 18        63       8           1            6871  904         100739
# 19        70       3           1            6778  772           8444
# 20        95       6           1            6739  930          55243
# 21       114       8           1            6725  920          40412
# 22        22       3           3            6705  842          13961
# 23        82       3           1            6701  785          14333
# 24         2       3           3            6650  822          12654
# 25        30       1           1            6596  885          18484
# 26       113       4           1            6573  862          38518
# 27       116       3           3            6545  802          15298
# 28        68       8           1            6488  875          24771
# 29        24       3           0            6481  747           5757
# ..       ...     ...         ...             ...  ...            ...
# 92        98       7           3            4459  696           5280
# 93        35       4           1            4362  694           3548
# 94         3       1           1            4360  749           3606
# 95        57       7           0            4356  585           1463
# 96       112       1           1            4324  746           2186
# 97        43       7           1            4276  588           1517
# 98        31       7           3            4272  452           1712
# 99        41       1           1            4252  776           3866
# 100       89       7           3            4236  612            498
# 101       92       7           1            4219  499            953
# 102       16       1           1            4217  810           7469
# 103      121       7           3            4193  532           1029
# 104       66       7           3            4156  474            300
# 105       40       7           3            4121  698           7079
# 106       67       7           1            4073  421            780
# 107       46       3           1            4028  496            735
# 108       14       7           3            3974  712           6954
# 109       25       7           3            3956  502            775
# 110       27       7           1            3916  486           1535
# 111       18       6           1            3907  576           1270
# 112        1       7           3            3866  577           3309
# 113       79       7           1            3856  351            368
# 114       21       7           1            3763  405            651
# 115       17       7           1            3739  420            614
# 116       65       7           3            3695  517            402
# 117      105       7           3            3666  533            878
# 118       61       7           1            3622  432            455
# 119       11       7           1            3484  512            789
# 120      107       7           1            3303  500            577
# 121      104       4           1            3069  536           2058
#
#      Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0               224                81             278
# 1               185               100             280
# 2               233                61              78
# 3               169                71             129
# 4               263               133              97
# 5               240               122             100
# 6               251                88             190
# 7               203                79             175
# 8               261                72             212
# 9               152                60             186
# 10               63                69               9
# 11              279                75             191
# 12              249               158              84
# 13              149                87              11
# 14              346               117             175
# 15              245               145              16
# 16              295                84             212
# 17              313               118             165
# 18              236               133             271
# 19              238                68               5
# 20               60                12              11
# 21              219               126             195
# 22              130               124             172
# 23              285               104              18
# 24              193                25             221
# 25              361               170             134
# 26               16               135               5
# 27              115                35             220
# 28              149               100             120
# 29              159                76               3
# ..              ...               ...             ...
# 92              225                76              81
# 93                6                 4               1
# 94               21               179              11
# 95               58                22               2
# 96              206               237              45
# 97               31                 3              10
# 98               32                 3               1
# 99               52               100             149
# 100              76                 1               9
# 101               9                 1               7
# 102             231               252              94
# 103              64                18               4
# 104               8                11               1
# 105             347                98              59
# 106               5                 1               1
# 107               1               326               1
# 108             173                35              35
# 109               1                 3               1
# 110              37                 1               7
# 111              57                65               1
# 112             217                57              45
# 113               3                 2               1
# 114              15                 1               1
# 115              25                 7               7
# 116              26                15               4
# 117              36                 6               1
# 118              19               152               2
# 119              34                 4              13
# 120              36                 2              19
# 121               5                35              16
#
# [122 rows x 9 columns]

# %% [markdown]
# ### Os dados da coluna *HappinessScore* são medidas de 2016, perguntando às pessoas: "Como você classificaria sua felicidade em uma escala de 0 a 10, onde 10 é a mais feliz?". Assim estão representados de forma errada, pois são médias de 0 a 10. Para corrigir isso, vamos dividir os dados da coluna por 1000

# %%
db['HappinessScore'] = db['HappinessScore']/1000

# %% [markdown]
# ### Removendo dados duplicados

# %%
db = db.drop_duplicates(None, 'first')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122 entries, 0 to 121
# Data columns (total 9 columns):
# Country             122 non-null int8
# Region              122 non-null int8
# Hemisphere          122 non-null int8
# HappinessScore      122 non-null float64
# HDI                 122 non-null int64
# GDP_PerCapita       122 non-null int64
# Beer_PerCapita      122 non-null int64
# Spirit_PerCapita    122 non-null int64
# Wine_PerCapita      122 non-null int64
# dtypes: float64(1), int64(5), int8(3)
# memory usage: 7.0 KB

# %% [markdown]
# ### Analisando a matriz de correlação

# %%
df = pd.DataFrame(db)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col1 {
#             background-color:  #acc0dd;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col2 {
#             background-color:  #dcdaeb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col3 {
#             background-color:  #d8d7e9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col4 {
#             background-color:  #e0deed;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col5 {
#             background-color:  #e3e0ee;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col6 {
#             background-color:  #fcf4fa;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col7 {
#             background-color:  #c2cbe2;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col0 {
#             background-color:  #f0eaf4;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col2 {
#             background-color:  #bcc7e1;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col3 {
#             background-color:  #ede8f3;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col4 {
#             background-color:  #fef6fa;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col5 {
#             background-color:  #abbfdc;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col6 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col7 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row1_col8 {
#             background-color:  #e1dfed;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col0 {
#             background-color:  #fbf3f9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col1 {
#             background-color:  #9cb9d9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col2 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col3 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col5 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col6 {
#             background-color:  #f4eef6;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col7 {
#             background-color:  #eae6f1;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row2_col8 {
#             background-color:  #fbf3f9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col0 {
#             background-color:  #f2ecf5;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col1 {
#             background-color:  #cccfe5;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col2 {
#             background-color:  #faf2f8;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col3 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col4 {
#             background-color:  #045f95;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col5 {
#             background-color:  #056faf;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col6 {
#             background-color:  #65a3cb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col7 {
#             background-color:  #76aad0;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row3_col8 {
#             background-color:  #80aed2;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col0 {
#             background-color:  #f7f0f7;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col1 {
#             background-color:  #e0dded;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col2 {
#             background-color:  #f8f1f8;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col3 {
#             background-color:  #045e94;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col4 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col5 {
#             background-color:  #0771b1;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col6 {
#             background-color:  #3b92c1;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col7 {
#             background-color:  #4897c4;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row4_col8 {
#             background-color:  #3991c1;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col0 {
#             background-color:  #efe9f3;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col1 {
#             background-color:  #6fa7ce;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col2 {
#             background-color:  #eee8f3;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col3 {
#             background-color:  #056caa;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col4 {
#             background-color:  #056dac;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col5 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col6 {
#             background-color:  #8fb4d6;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col7 {
#             background-color:  #a7bddb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row5_col8 {
#             background-color:  #4094c3;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col0 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col1 {
#             background-color:  #cacee5;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col2 {
#             background-color:  #d8d7e9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col3 {
#             background-color:  #4897c4;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col4 {
#             background-color:  #2987bc;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col5 {
#             background-color:  #84b0d3;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col6 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col7 {
#             background-color:  #529bc7;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row6_col8 {
#             background-color:  #76aad0;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col0 {
#             background-color:  #fef6fa;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col1 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col2 {
#             background-color:  #fff7fb;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col3 {
#             background-color:  #9fbad9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col4 {
#             background-color:  #75a9cf;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col5 {
#             background-color:  #e0dded;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col6 {
#             background-color:  #99b8d8;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col7 {
#             background-color:  #023858;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row7_col8 {
#             background-color:  #e7e3f0;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row8_col0 {
#             background-color:  #fef6fa;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row8_col1 {
#             background-color:  #96b6d7;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row8_col2 {
#             background-color:  #dad9ea;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row8_col3 {
#             background-color:  #5a9ec9;
#         }    #T_f081a5e8_dc97_11e8_b17a_50b7c341d975row8_col4 {
#             bac

# %% [markdown]
# ### Utilizando o boxplot para visualização de *outliers*.  Por se tratar do Índice de Produto Interno Bruto, a coluna GDP realmente tem dados distantes, então não é necessário a correção desses dados

# %%
sns.set(style="whitegrid", color_codes=True)
sns.boxplot(data=db);

# %% [markdown]
# ### Dividindo DB entre treinamento e teste, deixando como saida a coluna HappinessScore

# %%
features = list(db)
features.remove('HappinessScore')

# %%
X = db[features]
y = db['HappinessScore']

# %%
from sklearn.model_selection import train_test_split

 #70% treinamento e 30% teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# system library
import numpy as np

# user-library
import RegressionBase


# third-party library
from sklearn import neighbors
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.learning_curve import validation_curve
import matplotlib.pyplot as plt



class RegressionKNN(RegressionBase.RegressionBase):
    def __init__(self, isTrain):
        super(RegressionKNN, self).__init__(isTrain)
        # data preprocessing
        #self.dataPreprocessing()

        # Create KNN regression object
        # first parameter is the K neighbors
        # 'uniform' assigns uniform weights to each neighbor
        # 'distance' assigns weights proportional to the inverse of the distance from the query point
        # default metric is euclidean distance
        self.regr = neighbors.KNeighborsRegressor(86, weights='distance')

    def dataPreprocessing(self):
        # due to the observation, standization does not help the optimization.
        # So do not use it!
        #self.Standardization()
        pass

    def parameterChoosing(self):
        # Set the parameters by cross-validation
        tuned_parameters = [{'weights': ['uniform', 'distance'],
                             'n_neighbors': range(2,100)
                             }
                            ]


        reg = GridSearchCV(neighbors.KNeighborsRegressor(), tuned_parameters, cv=5, scoring='mean_squared_error')
        reg.fit(self.X_train, self.y_train)

        print ("Best parameters set found on development set:\n")
        print (reg.best_params_)

        print ("Grid scores on development set:\n")
        for params, mean_score, scores in reg.grid_scores_:
            print ("%0.3f (+/-%0.03f) for %r\n" % (mean_score, scores.std() * 2, params))

        print (reg.scorer_)
        print ("MSE for test data set:")
        y_true, y_pred = self.y_test, reg.predict(self.X_test)
        print (mean_squared_error(y_pred, y_true))

    def drawValidationCurve(self):
        """
        To draw the validation curve
        :return:NA
        """
        X, y = self.X_train, self.y_train.ravel()
        indices = np.arange(y.shape[0])
        #np.random.shuffle(indices)
        X, y = X[indices], y[indices]

        train_sizes = range(2,100,2)
        train_scores, valid_scores = validation_curve(self.regr, X, y, "n_neighbors",
                                              train_sizes, cv=5, scoring='mean_squared_error')
        train_scores = -1.0/5*train_scores
        valid_scores = -1.0/5*valid_scores

        train_scores_mean = np.mean(train_scores, axis=1)
        train_scores_std = np.std(train_scores, axis=1)
        valid_scores_mean = np.mean(valid_scores, axis=1)
        valid_scores_std = np.std(valid_scores, axis=1)

        plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
        plt.fill_between(train_sizes, valid_scores_mean - valid_scores_std,
                         valid_scores_mean + valid_scores_std, alpha=0.1, color="g")
        plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training MSE")
        plt.plot(train_sizes, valid_scores_mean, '*-', color="g",
                 label="Cross-validation MSE")

        plt.legend(loc="best")

        plt.xlabel('K Neighbors')
        plt.ylabel('MSE')
        plt.title('Validation Curve with KNN Regression on the parameter of K Neighbors')
        plt.grid(True)
        plt.show()

    def training(self):
        # train the linear regression model
        self.regr.fit(self.X_train, self.y_train)

    def predict(self):
        # predict the test data
        self.y_pred = self.regr.predict(self.X_test)

        # print MSE
        mse = mean_squared_error(self.y_pred, self.y_test)
        print ("MSE: {}".format(mse))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-9db70571eda6> in <module>
#       3
#       4 # user-library
# ----> 5 import RegressionBase
#       6
#       7
#
# ImportError: No module named 'RegressionBase'

# %%
model_cross_valid(X_test,y_test)
# Out:
# <class 'sklearn.linear_model.base.LinearRegression'> -0.6754918968580368
# <class 'sklearn.linear_model.coordinate_descent.ElasticNet'> -0.5656236897098844
