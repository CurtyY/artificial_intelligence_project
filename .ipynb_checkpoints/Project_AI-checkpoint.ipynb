# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import BayesianRidge, LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor

# %%
db = pd.read_csv('HappinessAlcoholConsumption.csv')

# %% [markdown]
# ## Pré-Processamento

# %% [markdown]
# ### O banco de dados não tem nenhum dado faltando, como mostrado abaixo

# %%
db.isnull().sum()
# Out:
# Country             0
# Region              0
# Hemisphere          0
# HappinessScore      0
# HDI                 0
# GDP_PerCapita       0
# Beer_PerCapita      0
# Spirit_PerCapita    0
# Wine_PerCapita      0
# dtype: int64

# %% [markdown]
# ### Visualizando a base de dados

# %%
db
# Out:
#                   Country                           Region Hemisphere  \
# 0                 Denmark                   Western Europe      north
# 1             Switzerland                   Western Europe      north
# 2                 Iceland                   Western Europe      north
# 3                  Norway                   Western Europe      north
# 4                 Finland                   Western Europe      north
# 5                  Canada                    North America      north
# 6             Netherlands                   Western Europe      north
# 7             New Zealand        Australia and New Zealand      south
# 8               Australia        Australia and New Zealand      south
# 9                  Sweden                   Western Europe      north
# 10                 Israel  Middle East and Northern Africa      north
# 11                Austria                   Western Europe      north
# 12          United States                    North America      north
# 13             Costa Rica      Latin America and Caribbean      north
# 14                Germany                   Western Europe      north
# 15                 Brazil      Latin America and Caribbean       both
# 16                Belgium                   Western Europe      north
# 17                Ireland                   Western Europe      north
# 18             Luxembourg                   Western Europe      north
# 19                 Mexico      Latin America and Caribbean      north
# 20              Singapore                Southeastern Asia      north
# 21         United Kingdom                   Western Europe      north
# 22                  Chile      Latin America and Caribbean      south
# 23                 Panama      Latin America and Caribbean      north
# 24              Argentina      Latin America and Caribbean      south
# 25         Czech Republic       Central and Eastern Europe      north
# 26   United Arab Emirates  Middle East and Northern Africa      north
# 27                Uruguay      Latin America and Caribbean      south
# 28                  Malta                   Western Europe      north
# 29               Colombia      Latin America and Caribbean       both
# ..                    ...                              ...        ...
# 92           South Africa               Sub-Saharan Africa      south
# 93                  Egypt  Middle East and Northern Africa      north
# 94                Armenia       Central and Eastern Europe      north
# 95                  Kenya               Sub-Saharan Africa       both
# 96                Ukraine       Central and Eastern Europe      north
# 97                  Ghana               Sub-Saharan Africa      north
# 98        Dem. Rep. Congo               Sub-Saharan Africa      south
# 99                Georgia       Central and Eastern Europe      north
# 100            Rep. Congo               Sub-Saharan Africa      south
# 101               Senegal               Sub-Saharan Africa      north
# 102              Bulgaria       Central and Eastern Europe      north
# 103              Zimbabwe               Sub-Saharan Africa      south
# 104                Malawi               Sub-Saharan Africa      south
# 105                 Gabon               Sub-Saharan Africa      south
# 106                  Mali               Sub-Saharan Africa      north
# 107                 Haiti      Latin America and Caribbean      north
# 108              Botswana               Sub-Saharan Africa      south
# 109               Comoros               Sub-Saharan Africa      south
# 110         Cote d'Ivoire               Sub-Saharan Africa      north
# 111              Cambodia                Southeastern Asia      north
# 112                Angola               Sub-Saharan Africa      south
# 113                 Niger               Sub-Saharan Africa      north
# 114                  Chad               Sub-Saharan Africa      north
# 115          Burkina Faso               Sub-Saharan Africa      north
# 116            Madagascar               Sub-Saharan Africa      south
# 117              Tanzania               Sub-Saharan Africa      south
# 118               Liberia               Sub-Saharan Africa      north
# 119                 Benin               Sub-Saharan Africa      north
# 120                  Togo               Sub-Saharan Africa      north
# 121                 Syria  Middle East and Northern Africa      north
#
#      HappinessScore  HDI  GDP_PerCapita  Beer_PerCapita  Spirit_PerCapita  \
# 0              7526  928          53579             224                81
# 1              7509  943          79866             185               100
# 2              7501  933          60530             233                61
# 3              7498  951          70890             169                71
# 4              7413  918          43433             263               133
# 5              7404  922          42349             240               122
# 6              7339  928          45638             251                88
# 7              7334  915          40332             203                79
# 8              7313  938          49897             261                72
# 9              7291  932          51845             152                60
# 10             7267  902          37181              63                69
# 11             7119  906          44731             279                75
# 12             7104  922          57589             249               158
# 13             7087  791          11733             149                87
# 14             6994  934          42233             346               117
# 15             6952  758           8639             245               145
# 16             6929  915          41261             295                84
# 17             6907  934          64100             313               118
# 18             6871  904         100739             236               133
# 19             6778  772           8444             238                68
# 20             6739  930          55243              60                12
# 21             6725  920          40412             219               126
# 22             6705  842          13961             130               124
# 23             6701  785          14333             285               104
# 24             6650  822          12654             193                25
# 25             6596  885          18484             361               170
# 26             6573  862          38518              16               135
# 27             6545  802          15298             115                35
# 28             6488  875          24771             149               100
# 29             6481  747           5757             159                76
# ..              ...  ...            ...             ...               ...
# 92             4459  696           5280             225                76
# 93             4362  694           3548               6                 4
# 94             4360  749           3606              21               179
# 95             4356  585           1463              58                22
# 96             4324  746           2186             206               237
# 97             4276  588           1517              31                 3
# 98             4272  452           1712              32                 3
# 99             4252  776           3866              52               100
# 100            4236  612            498              76                 1
# 101            4219  499            953               9                 1
# 102            4217  810           7469             231               252
# 103            4193  532           1029              64                18
# 104            4156  474            300               8                11
# 105            4121  698           7079             347                98
# 106            4073  421            780               5                 1
# 107            4028  496            735               1               326
# 108            3974  712           6954             173                35
# 109            3956  502            775               1                 3
# 110            3916  486           1535              37                 1
# 111            3907  576           1270              57                65
# 112            3866  577           3309             217                57
# 113            3856  351            368               3                 2
# 114            3763  405            651              15                 1
# 115            3739  420            614              25                 7
# 116            3695  517            402              26                15
# 117            3666  533            878              36                 6
# 118            3622  432            455              19               152
# 119            3484  512            789              34                 4
# 120            3303  500            577              36                 2
# 121            3069  536           2058               5                35
#
#      Wine_PerCapita
# 0               278
# 1               280
# 2                78
# 3               129
# 4                97
# 5               100
# 6               190
# 7               175
# 8               212
# 9               186
# 10                9
# 11              191
# 12               84
# 13               11
# 14              175
# 15               16
# 16              212
# 17              165
# 18              271
# 19                5
# 20               11
# 21              195
# 22              172
# 23               18
# 24              221
# 25              134
# 26                5
# 27              220
# 28              120
# 29                3
# ..              ...
# 92               81
# 93                1
# 94               11
# 95                2
# 96               45
# 97               10
# 98                1
# 99              149
# 100               9
# 101               7
# 102              94
# 103               4
# 104               1
# 105              59
# 106               1
# 107               1
# 108              35
# 109               1
# 110               7
# 111               1
# 112              45
# 113               1
# 114               1
# 115               7
# 116               4
# 117               1
# 118               2
# 119              13
# 120              19
# 121              16
#
# [122 rows x 9 columns]

# %% [markdown]
# ### Os dados da coluna *HappinessScore* são medidas de 2016, perguntando às pessoas: "Como você classificaria sua felicidade em uma escala de 0 a 10, onde 10 é a mais feliz?". Assim estão representados de forma errada, pois são médias de 0 a 10. Para corrigir isso, vamos dividir os dados da coluna por 1000

# %%
db['HappinessScore'] = db['HappinessScore']/1000

# %% [markdown]
# ### Os dados das colunas *Hemisphere* e *Region* são desnecessários, optamos então por removê-las

# %%
del db['Hemisphere']
del db['Region']
del db['Country']

# %%
db['HappinessScore']
# Out:
# 0      7.526
# 1      7.509
# 2      7.501
# 3      7.498
# 4      7.413
# 5      7.404
# 6      7.339
# 7      7.334
# 8      7.313
# 9      7.291
# 10     7.267
# 11     7.119
# 12     7.104
# 13     7.087
# 14     6.994
# 15     6.952
# 16     6.929
# 17     6.907
# 18     6.871
# 19     6.778
# 20     6.739
# 21     6.725
# 22     6.705
# 23     6.701
# 24     6.650
# 25     6.596
# 26     6.573
# 27     6.545
# 28     6.488
# 29     6.481
#        ...
# 92     4.459
# 93     4.362
# 94     4.360
# 95     4.356
# 96     4.324
# 97     4.276
# 98     4.272
# 99     4.252
# 100    4.236
# 101    4.219
# 102    4.217
# 103    4.193
# 104    4.156
# 105    4.121
# 106    4.073
# 107    4.028
# 108    3.974
# 109    3.956
# 110    3.916
# 111    3.907
# 112    3.866
# 113    3.856
# 114    3.763
# 115    3.739
# 116    3.695
# 117    3.666
# 118    3.622
# 119    3.484
# 120    3.303
# 121    3.069
# Name: HappinessScore, Length: 122, dtype: float64

# %% [markdown]
# ### Removendo dados duplicados

# %%
db = db.drop_duplicates(None, 'first')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122 entries, 0 to 121
# Data columns (total 6 columns):
# HappinessScore      122 non-null float64
# HDI                 122 non-null int64
# GDP_PerCapita       122 non-null int64
# Beer_PerCapita      122 non-null int64
# Spirit_PerCapita    122 non-null int64
# Wine_PerCapita      122 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 6.7 KB

# %% [markdown]
# ### Analisando a matriz de correlação

# %%
df = pd.DataFrame(db)
corr = df.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col0 {
#             background-color:  #023858;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col1 {
#             background-color:  #1b7eb7;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col2 {
#             background-color:  #197db7;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col3 {
#             background-color:  #dbdaeb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col4 {
#             background-color:  #dddbec;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col5 {
#             background-color:  #a5bddb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col0 {
#             background-color:  #056faf;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col1 {
#             background-color:  #023858;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col2 {
#             background-color:  #1e80b8;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col3 {
#             background-color:  #adc1dd;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col4 {
#             background-color:  #b1c2de;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col5 {
#             background-color:  #5c9fc9;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col0 {
#             background-color:  #358fc0;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col1 {
#             background-color:  #67a4cc;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col2 {
#             background-color:  #023858;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col3 {
#             background-color:  #f9f2f8;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col5 {
#             background-color:  #65a3cb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col0 {
#             background-color:  #b9c6e0;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col1 {
#             background-color:  #b8c6e0;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col2 {
#             background-color:  #b3c3de;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col3 {
#             background-color:  #023858;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col4 {
#             background-color:  #bcc7e1;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col5 {
#             background-color:  #9ab8d8;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col0 {
#             background-color:  #fff7fb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col3 {
#             background-color:  #fff7fb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col4 {
#             background-color:  #023858;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col5 {
#             background-color:  #fff7fb;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row5_col0 {
#             background-color:  #cdd0e5;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row5_col1 {
#             background-color:  #b0c2de;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row5_col2 {
#             background-color:  #5c9fc9;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row5_col3 {
#             background-color:  #e1dfed;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row5_col4 {
#             background-color:  #f9f2f8;
#         }    #T_bc9a5316_dc5a_11e8_990d_50b7c341d975row5_col5 {
#             background-color:  #023858;
#         }</style>
# <table id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >HappinessScore</th>
#         <th class="col_heading level0 col1" >HDI</th>
#         <th class="col_heading level0 col2" >GDP_PerCapita</th>
#         <th class="col_heading level0 col3" >Beer_PerCapita</th>
#         <th class="col_heading level0 col4" >Spirit_PerCapita</th>
#         <th class="col_heading level0 col5" >Wine_PerCapita</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975level0_row0" class="row_heading level0 row0" >HappinessScore</th>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col0" class="data row0 col0" >1</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col1" class="data row0 col1" >0.82</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col2" class="data row0 col2" >0.72</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col3" class="data row0 col3" >0.49</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col4" class="data row0 col4" >0.26</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row0_col5" class="data row0 col5" >0.45</td>
#     </tr>    <tr>
#         <th id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975level0_row1" class="row_heading level0 row1" >HDI</th>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col0" class="data row1 col0" >0.82</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col1" class="data row1 col1" >1</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col2" class="data row1 col2" >0.71</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col3" class="data row1 col3" >0.59</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col4" class="data row1 col4" >0.39</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row1_col5" class="data row1 col5" >0.6</td>
#     </tr>    <tr>
#         <th id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975level0_row2" class="row_heading level0 row2" >GDP_PerCapita</th>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col0" class="data row2 col0" >0.72</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col1" class="data row2 col1" >0.71</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col2" class="data row2 col2" >1</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col3" class="data row2 col3" >0.39</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col4" class="data row2 col4" >0.08</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row2_col5" class="data row2 col5" >0.59</td>
#     </tr>    <tr>
#         <th id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975level0_row3" class="row_heading level0 row3" >Beer_PerCapita</th>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col0" class="data row3 col0" >0.49</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col1" class="data row3 col1" >0.59</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col2" class="data row3 col2" >0.39</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col3" class="data row3 col3" >1</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col4" class="data row3 col4" >0.36</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row3_col5" class="data row3 col5" >0.47</td>
#     </tr>    <tr>
#         <th id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975level0_row4" class="row_heading level0 row4" >Spirit_PerCapita</th>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col0" class="data row4 col0" >0.26</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col1" class="data row4 col1" >0.39</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col2" class="data row4 col2" >0.08</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col3" class="data row4 col3" >0.36</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col4" class="data row4 col4" >1</td>
#         <td id="T_bc9a5316_dc5a_11e8_990d_50b7c341d975row4_col5" class="data row4 col5" >0.12</td>
#     </tr>    <tr>
#         <th

# %% [markdown]
# ### Utilizando o boxplot para visualização de *outliers*.  Por se tratar do Índice de Produto Interno Bruto, a coluna GDP realmente tem dados distantes, então não é necessário a correção desses dados

# %%
sns.set(style="whitegrid", color_codes=True)
sns.boxplot(data=db);

# %% [markdown]
# ### Dividindo DB entre treinamento e teste, deixando como saida a coluna HappinessScore

# %%
X_train = db
y_train = db.iloc[:,0]
del X_train['HappinessScore']

# %%
X_train.head()
# Out:
#    HDI  GDP_PerCapita  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0  928          53579             224                81             278
# 1  943          79866             185               100             280
# 2  933          60530             233                61              78
# 3  951          70890             169                71             129
# 4  918          43433             263               133              97

# %%
y_train.head()
# Out:
# 0    7.526
# 1    7.509
# 2    7.501
# 3    7.498
# 4    7.413
# Name: HappinessScore, dtype: float64

# %%
#from sklearn.model_selection import train_test_split

# 70% treinamento e 30% teste
#X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.3)

# %%
# Função que retorna os resultados do modelo
from sklearn.model_selection import train_test_split

def retornaResultadosModeloKNN_Regressao(random_state, quantidade, dados, respostas):
    #Divisão entre observações de teste e observações de treino
    X_train, X_test, y_train, y_test = train_test_split(dados, respostas, random_state = random_state)
    # Vetores de armazenamento dos resultados de teste e de treino
    quantidade_k = range(1,quantidade + 1)
    res_teste = []
    res_treino = []
    
    # loop das classificações

    for i in quantidade_k:
        knn = KNeighborsRegressor(n_neighbors = i)
        knn.fit(X_train, y_train)

        # Adicionando os valores dos resultados a seus respectivos vetores
        res_treino.append(knn.score(X_train, y_train))
        res_teste.append(knn.score(X_test, y_test))
        
    return quantidade_k, res_treino, res_teste

# %%
# Print de alguns resultados
quantidade_k, res_treino, res_teste = retornaResultadosModeloKNN_Regressao(100, 30, X_train, y_train)
i = 4
print("Treino {} : {}".format(i, res_treino[i]))
print("Teste {} : {}".format(i, res_teste[i]))
# Out:
# Treino 4 : 0.7999781595778623
# Teste 4 : 0.5139165875393421

# %%
# Plot dos gráficos com os seguintes randoms 1, 5, 20, 550
dados = X_train
respostas = y_train

legendas = ["Treino", "Teste"]
quantidade = 20
rand = 1
f, axarr = plt.subplots(2,2)
plt.rcParams["figure.figsize"] = [12,12]
plt.setp(axarr, xticks=np.arange(0,20, step=1))
quantidade_k, res_treino, res_teste = retornaResultadosModeloKNN_Regressao(rand, quantidade, dados, respostas)
axarr[0,0].plot(res_treino)
axarr[0,0].plot(res_teste)
axarr[0,0].grid(True)
axarr[0,0].set_title("Rand 1")
axarr[0,0].legend(legendas)

# Rand 5
rand = 5
quantidade_k, res_treino, res_teste = retornaResultadosModeloKNN_Regressao(rand, quantidade, dados, respostas)
axarr[0,1].plot(res_treino)
axarr[0,1].plot(res_teste)
axarr[0,1].grid(True)
axarr[0,1].set_title("Rand 5")
axarr[0,1].legend(legendas)

#Rand 20
rand = 20
quantidade_k, res_treino, res_teste = retornaResultadosModeloKNN_Regressao(rand, quantidade, dados, respostas)
axarr[1,0].plot(res_treino)
axarr[1,0].plot(res_teste)
axarr[1,0].grid(True)
axarr[1,0].set_title("Rand 20")
axarr[1,0].legend(legendas)

#Rand 550
rand = 550
quantidade_k, res_treino, res_teste = retornaResultadosModeloKNN_Regressao(rand, quantidade, dados, respostas)
axarr[1,1].plot(res_treino)
axarr[1,1].plot(res_teste)
axarr[1,1].grid(True)
axarr[1,1].set_title("Rand 550")
axarr[1,1].legend(legendas)

#plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
#plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)
plt.show()

# %%
dados = X_train
respostas = y_train

legendas = ["Treino", "Teste"]
quantidade = 20
rand = 5
quantidade_k, res_treino, res_teste = retornaResultadosModeloKNN_Regressao(rand, quantidade, dados, respostas)
plt.rcParams["figure.figsize"] = [8,8]
plt.plot(res_treino)
plt.plot(res_teste)
plt.legend(legendas)
plt.grid(True)
plt.xticks(np.arange(0,20, step=1))
plt.show()
